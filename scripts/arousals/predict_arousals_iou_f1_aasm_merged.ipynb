# %% [markdown]
# # Arousal Detection Evaluation using High-Frequency Sleep Staging
#
# This notebook evaluates arousal detection performance by treating short wake episodes
# predicted by high-frequency sleep staging models as arousal events.
#
# ## Overview
#
# Arousals are brief awakenings during sleep that disrupt sleep architecture. This notebook
# tests whether high-frequency sleep stage predictions (with temporal resolution finer than
# 30 seconds) can detect these events by identifying short wake periods.
#
# ## Method
#
# 1. **Load ground truth arousals** from MASS dataset annotation files (EDF format)
#    - Uses timing offsets from `mass_offsets.py` to align annotations with trimmed PSG data
#
# 2. **Load sleep stage predictions** from high-frequency model sweep
#    - Multiple temporal resolutions tested (1-3840 predictions per 30s epoch)
#
# 3. **Convert wake predictions to arousal events**
#    - Find continuous wake periods (sleep stage = 0)
#    - Merge nearby events (within 10% of merged duration, max 15s total)
#    - Filter by duration: 3-15 seconds (AASM arousal criteria)
#    - Require ≥10s of sleep before each arousal
#
# 4. **Evaluate using IoU-based metrics**
#    - Calculate Intersection over Union between predicted and ground truth arousals
#    - Compute precision, recall, F1 at multiple IoU thresholds (0.0 to 1.0)
#
# ## Outputs
#
# - `arousals_aasm_merged.json`: Predicted arousal events per model/resolution/subject
# - `arousals_iou_scores_aasm_merged.json`: Precision/recall/F1 scores at each IoU threshold
#
# ## Dependencies
#
# - High-frequency prediction files from `predict-high-freq.py` sweep

# %%
import gc
import glob
import json
from os.path import dirname

import mne
import numpy as np

from scripts.arousals.mass_offsets import offsets


def load_arousals(ann_file):
    # <Event channel="EEG C4-LER" groupName="MicroArousal" name="CARSM expert" scoringType="expert"/>
    data = mne.io.read_raw_edf(ann_file, verbose=False)
    s_id = ann_file.split("/")[-1].split(" ")[0]
    arousals = [
        (ann["onset"], ann["onset"] + ann["duration"])
        for ann in data.annotations
        if "MicroArousal" in ann["description"]
    ]
    channels = [
        ann["description"][ann["description"].find("channel") + 9:ann["description"].find("groupName") - 2]
        for ann in data.annotations
        if "MicroArousal" in ann["description"]
    ]
    if len(arousals) == 0:
        return arousals
    arousals = np.array([list(ar) + [ch] for ar, ch in zip(arousals, channels) if ch.startswith("EEG")])
    arousals[:, :2] = arousals[:, :2].astype(float) - offsets[f"mass-c{s_id.split('-')[1][1]}"][s_id]
    return arousals


def load_hf_sleep_stages(sweep_folder):
    labels_glob = f"{sweep_folder}/*/labels.npz"
    preds_glob = f"{sweep_folder}/*/predictions.npz"
    labels_files = sorted(glob.glob(labels_glob), key=lambda x: int(x.split("/")[-2]))
    preds_files = sorted(glob.glob(preds_glob), key=lambda x: int(x.split("/")[-2]))

    labels_per_sr_per_model = {}
    preds_per_sr_per_model = {}
    for label_file, pred_file in zip(labels_files, preds_files):
        with open(dirname(label_file) + "/predict-high-freq.log") as f:
            lines = f.readlines()
            sr_line = [line for line in lines if "sleep_stage_frequency" in line][0]
            sleep_stage_sr = int(sr_line.split("=")[1])
            model_line = [line for line in lines if "model.path" in line][0]
            model = model_line.split("=")[1]

        if model not in labels_per_sr_per_model:
            labels_per_sr_per_model[model] = {}
            preds_per_sr_per_model[model] = {}
        labels_per_sr_per_model[model][sleep_stage_sr] = np.load(label_file)
        preds_per_sr_per_model[model][sleep_stage_sr] = np.load(pred_file)

    return labels_per_sr_per_model, preds_per_sr_per_model


# TODO: replace with path to MASS data
arousal_files = glob.glob("/home/niklas/data/MASS/*Annotations.edf")

all_arousals = {}
for af in arousal_files:
    s_id = af.split('/')[-1].split(' ')[0]
    print(f"Processing {s_id}")
    arousals = load_arousals(af)

    all_arousals[s_id] = arousals
    if len(arousals) == 0:
        print(f"No arousals found in {af}")
        continue

    # check if theres overlap between arousals
    arousals = arousals[np.argsort(arousals[:, 0].astype(float))]
    overlap_mask = (arousals[1:, 0].astype(float) < arousals[:-1, 1].astype(float))
    if np.any(overlap_mask):
        print(f"Overlapping arousals found in {af}")
        print(arousals[np.r_[overlap_mask, False]])
        print(arousals[np.r_[False, overlap_mask]])

    gc.collect()
# Out:
# Processing 01-01-0020
# Processing 01-03-0060
# Processing 01-03-0010
# Processing 01-01-0005
# Processing 01-01-0041
# Processing 01-03-0057
# Processing 01-01-0006
# Processing 01-03-0037
# Processing 01-03-0038
# Processing 01-03-0016
# Processing 01-03-0042
# Processing 01-03-0031
# Processing 01-03-0064
# Processing 01-01-0011
# Processing 01-01-0040
# Processing 01-01-0019
# Processing 01-03-0008
# Processing 01-03-0025
# Processing 01-03-0061
# Processing 01-03-0033
# Processing 01-03-0005
# Processing 01-03-0020
# Processing 01-03-0017
# Processing 01-01-0002
# Processing 01-03-0052
# Processing 01-01-0037
# Processing 01-01-0023
# Processing 01-01-0033
# Processing 01-01-0031
# Processing 01-03-0044
# Processing 01-01-0013
# Processing 01-03-0056
# Processing 01-01-0051
# Processing 01-03-0047
# Processing 01-01-0046
# Processing 01-03-0046
# Processing 01-01-0016
# Processing 01-01-0018
# Processing 01-01-0042
# Processing 01-03-0062
# Processing 01-01-0022
# Processing 01-01-0015
# Processing 01-03-0063
# Processing 01-01-0027
# Processing 01-03-0027
# Processing 01-03-0011
# Processing 01-01-0012
# Overlapping arousals found in /home/niklas/data/MASS/01-01-0012 Annotations.edf
# [['25254.870139' '25263.514112999997' 'EEG C3-LER']
#  ['28704.034097' '28721.470483' 'EEG C3-LER']]
# [['25255.79307' '25263.245714' 'EEG C4-LER']
#  ['28705.763079' '28718.648974' 'EEG C4-LER']]
# Processing 01-01-0052
# Overlapping arousals found in /home/niklas/data/MASS/01-01-0052 Annotations.edf
# [['20561.144141' '20573.03987' 'EEG C4-LER']
#  ['20632.908126' '20641.30017' 'EEG C4-LER']]
# [['20561.663046' '20570.291403000003' 'EEG C4-LER']
#  ['20633.912062' '20640.917471' 'EEG C4-LER']]
# Processing 01-03-0059
# Processing 01-01-0049
# Processing 01-03-0006
# Processing 01-01-0026
# Processing 01-03-0019
# Processing 01-01-0044
# Processing 01-01-0043
# Processing 01-03-0030
# Processing 01-01-0014
# Processing 01-03-0013
# Processing 01-01-0008
# Processing 01-03-0032
# Processing 01-03-0007
# Overlapping arousals found in /home/niklas/data/MASS/01-03-0007 Annotations.edf
# [['2269.195956' '2278.406306' 'EEG C4-LER']
#  ['8400.101035' '8406.350638' 'EEG C3-LER']
#  ['12190.929972' '12199.359124999999' 'EEG C3-LER']
#  ['16301.891046' '16311.753694' 'EEG C3-LER']
#  ['18630.215075' '18637.624758' 'EEG C4-LER']
#  ['20190.332087' '20201.487627' 'EEG C4-LER']
#  ['21313.809059' '21327.472252' 'EEG C3-LER']
#  ['23431.496045' '23442.878125' 'EEG C4-LER']]
# [['2270.65305' '2276.652669' 'EEG C3-LER']
#  ['8400.557935' '8407.463742' 'EEG C4-LER']
#  ['12191.868032' '12200.617467' 'EEG C4-LER']
#  ['16302.371077' '16309.679205' 'EEG C4-LER']
#  ['18631.82505' '18636.816917' 'EEG C3-LER']
#  ['20190.559102' '20199.480412' 'EEG C3-LER']
#  ['21317.731053' '21330.980206' 'EEG C4-LER']
#  ['23431.918071' '23441.835407' 'EEG C3-LER']]
# Processing 01-03-0023
# Processing 01-01-0047
# Processing 01-03-0003
# Processing 01-03-0051
# Processing 01-01-0024
# Processing 01-01-0003
# Processing 01-03-0036
# Processing 01-03-0022
# Processing 01-03-0002
# Processing 01-03-0034
# Processing 01-03-0054
# Processing 01-03-0014
# Processing 01-01-0030
# Processing 01-03-0004
# Processing 01-01-0053
# Processing 01-03-0009
# Processing 01-03-0028
# Processing 01-01-0001
# Processing 01-01-0010
# Processing 01-03-0026
# Processing 01-03-0029
# Processing 01-03-0058
# Processing 01-03-0035
# Overlapping arousals found in /home/niklas/data/MASS/01-03-0035 Annotations.edf
# [['10818.140044' '10832.451627999999' 'EEG P3-LER']]
# [['10822.257052' '10832.443896' 'EEG C4-LER']]
# Processing 01-03-0012
# Processing 01-01-0004
# Processing 01-01-0025
# Processing 01-03-0001
# Processing 01-01-0035
# Processing 01-01-0039
# Processing 01-03-0040
# Processing 01-01-0021
# Processing 01-03-0024
# Processing 01-01-0050
# Processing 01-03-0050
# Processing 01-03-0021
# Processing 01-03-0039
# Processing 01-01-0045
# Processing 01-01-0029
# Processing 01-01-0048
# Processing 01-03-0041
# No arousals found in /home/niklas/data/MASS/01-03-0041 Annotations.edf
# Processing 01-01-0036
# Processing 01-01-0032
# Processing 01-03-0018
# Processing 01-01-0038
# Processing 01-01-0028
# Processing 01-03-0053
# Processing 01-01-0007
# Processing 01-03-0045
# Processing 01-01-0009
# Processing 01-01-0034
# Processing 01-01-0017
# Processing 01-03-0015
# Processing 01-03-0055
# Processing 01-03-0048

# %%
def merge_arousals(arousals, max_after_merge_dur=15, max_merge_dist_perc=0.1):
    if len(arousals) == 0:
        return np.array(arousals)
    # Sort events by start time to ensure "consecutive" logic is correct.
    sorted_events = sorted(arousals, key=lambda x: x[0])

    merged_events = [sorted_events[0]]

    n_merges = 0
    for current_event in sorted_events[1:]:
        last_merged_event = merged_events[-1]

        merged_duration = current_event[1] - last_merged_event[0]
        distance = current_event[0] - last_merged_event[1]

        if (merged_duration <= max_after_merge_dur and
                distance <= merged_duration * max_merge_dist_perc):
            merged_events[-1][1] = current_event[1]
            n_merges += 1
        else:
            merged_events.append(current_event)

    print(f"Merged {n_merges} arousals, remaining {len(merged_events)}")

    return np.array(merged_events)

# %%
pred_arousals = {}
# {sleep_stage_sr: {wake_length: {s_id: arousals}}}

hf_ss_sweep_folder = "../../logs/exp002/exp002a/sweep-2025-07-28_19-56-55_mass/"
_, hf_ss = load_hf_sleep_stages(hf_ss_sweep_folder)

for model in hf_ss.keys():
    pred_arousals[model] = {}

    for ss_sr in hf_ss[model].keys():
        pred_arousals[model][ss_sr] = {}

        lower_wake_length = 3
        upper_wake_length = 15

        pred_arousals[model][ss_sr] = {}
        print(f"Processing {ss_sr} {lower_wake_length} {upper_wake_length}")

        for s_id_ss in hf_ss[model][ss_sr].keys():
            hf_ss_sr = hf_ss[model][ss_sr][s_id_ss]
            # get continuous wake sleep stages of at least lower_wake_length and at most upper_wake_length
            wake_mask = hf_ss_sr == 0
            wake_borders = np.diff(wake_mask, prepend=0, append=0)
            wake_starts = np.where(wake_borders == 1)[0]
            wake_ends = np.where(wake_borders == -1)[0]
            assert len(wake_starts) == len(wake_ends)
            if len(wake_starts) == 0:
                continue

            arousals = np.column_stack((wake_starts, wake_ends)) / ss_sr * 30
            arousals = merge_arousals(arousals)

            # remove wake events with less than 10s of sleep before
            sleep_before_lengths = (arousals[:, 0] - np.r_[0, arousals[:-1, 1]])
            arousals = arousals[sleep_before_lengths >= 10]

            wake_lengths = arousals[:, 1] - arousals[:, 0]
            arousals = arousals[(lower_wake_length <= wake_lengths) & (wake_lengths <= upper_wake_length)]
            pred_arousals[model][ss_sr][s_id_ss] = arousals
# Out:
# Processing 1 3 15
# Merged 0 arousals, remaining 30
# Merged 0 arousals, remaining 37
# Merged 0 arousals, remaining 26
# Merged 0 arousals, remaining 51
# Merged 0 arousals, remaining 37
# Merged 0 arousals, remaining 42
# Merged 0 arousals, remaining 30
# Merged 0 arousals, remaining 24
# Merged 0 arousals, remaining 41
# Merged 0 arousals, remaining 36
# Merged 0 arousals, remaining 55
# Merged 0 arousals, remaining 58
# Merged 0 arousals, remaining 28
# Merged 0 arousals, remaining 27
# Merged 0 arousals, remaining 43
# Merged 0 arousals, remaining 18
# Merged 0 arousals, remaining 60
# Merged 0 arousals, remaining 37
# Merged 0 arousals, remaining 47
# Merged 0 arousals, remaining 56
# Merged 0 arousals, remaining 60
# Merged 0 arousals, remaining 33
# Merged 0 arousals, remaining 47
# Merged 0 arousals, remaining 41
# Merged 0 arousals, remaining 33
# Merged 0 arousals, remaining 25
# Merged 0 arousals, remaining 22
# Merged 0 arousals, remaining 28
# Merged 0 arousals, remaining 29
# Merged 0 arousals, remaining 23
# Merged 0 arousals, remaining 43
# Merged 0 arousals, remaining 28
# Merged 0 arousals, remaining 44
# Merged 0 arousals, remaining 16
# Merged 0 arousals, remaining 28
# Merged 0 arousals, remaining 22
# Merged 0 arousals, remaining 13
# Merged 0 arousals, remaining 29
# Merged 0 arousals, remaining 50
# Merged 0 arousals, remaining 33
# Merged 0 arousals, remaining 37
# Merged 0 arousals, remaining 19
# Merged 0 arousals, remaining 22
# Merged 0 arousals, remaining 24
# Merged 0 arousals, remaining 51
# Merged 0 arousals, remaining 49
# Merged 0 arousals, remaining 46
# Merged 0 arousals, remaining 36
# Merged 0 arousals, remaining 21
# Merged 0 arousals, remaining 32
# Merged 0 arousals, remaining 46
# Merged 0 arousals, remaining 44
# Merged 0 arousals, remaining 46
# Merged 0 arousals, remaining 19
# Merged 0 arousals, remaining 29
# Merged 0 arousals, remaining 22
# Merged 0 arousals, remaining 11
# Merged 0 arousals, remaining 28
# Merged 0 arousals, remaining 39
# Merged 0 arousals, remaining 25
# Merged 0 arousals, remaining 16
# Merged 0 arousals, remaining 59
# Merged 0 arousals, remaining 9
# Merged 0 arousals, remaining 19
# Merged 0 arousals, remaining 25
# Merged 0 arousals, remaining 33
# Merged 0 arousals, remaining 28
# Merged 0 arousals, remaining 27
# Merged 0 arousals, remaining 34
# Merged 0 arousals, remaining 33
# Merged 0 arousals, remaining 28
# Merged 0 arousals, remaining 34
# Merged 0 arousals, remaining 31
# Merged 0 arousals, remaining 17
# Merged 0 arousals, remaining 15
# Merged 0 arousals, remaining 28
# Merged 0 arousals, remaining 53
# Merged 0 arousals, remaining 27
# Merged 0 arousals, remaining 18
# Merged 0 arousals, remaining 26
# Merged 0 arousals, remaining 24
# Merged 0 arousals, remaining 28
# Merged 0 arousals, remaining 44
# Merged 0 arousals, remaining 40
# Merged 0 arousals, remaining 32
# Merged 0 arousals, remaining 15
# Merged 0 arousals, remaining 22
# Merged 0 arousals, remaining 47
# Merged 0 arousals, remaining 34
# Merged 0 arousals, remaining 16
# Merged 0 arousals, remaining 36
# Merged 0 arousals, remaining 24
# Merged 0 arousals, remaining 31
# Merged 0 arousals, remaining 26
# Merged 0 arousals, remaining 21
# Merged 0 arousals, remaining 23
# Merged 0 arousals, remaining 22
# Merged 0 arousals, remaining 14
# Merged 0 arousals, remaining 48
# Merged 0 arousals, remaining 33
# Merged 0 arousals, remaining 27
# Merged 0 arousals, remaining 24
# Merged 0 arousals, remaining 27
# Merged 0 arousals, remaining 25
# Merged 0 arousals, remaining 39
# Merged 0 arousals, remaining 31
# Merged 0 arousals, remaining 37
# Merged 0 arousals, remaining 25
# Merged 0 arousals, remaining 36
# Merged 0 arousals, remaining 24
# Merged 0 arousals, remaining 21
# Merged 0 arousals, remaining 33
# Merged 0 arousals, remaining 34
# Merged 0 arousals, remaining 15
# Merged 0 arousals, remaining 13
# Processing 2 3 15
# Merged 0 arousals, remaining 54
# Merged 0 arousals, remaining 71
# Merged 0 arousals, remaining 42
# Merged 0 arousals, remaining 88
# Merged 0 arousals, remaining 83
# Merged 0 arousals, remaining 93
# Merged 0 arousals, remaining 56
# Merged 0 arousals, remaining 46
# Merged 0 arousals, remaining 65
# Merged 0 arousals, remaining 54
# Merged 0 arousals, remaining 104
# Merged 0 arousals, remaining 106
# Merged 0 arousals, remaining 57
# Merged 0 arousals, remaining 47
# Merged 0 arousals, remaining 106
# Merged 0 arousals, remaining 31
# Merged 0 arousals, remaining 123
# Merged 0 arousals, remaining 86
# Merged 0 arousals, remaining 76
# Merged 0 arousals, remaining 115
# Merged 0 arousals, remaining 128
# Merged 0 arousals, remaining 61
# Merged 0 arousals, remaining 95
# Merged 0 arousals, remaining 105
# Merged 0 arousals, remaining 68
# Merged 0 arousals, remaining 51
# Merged 0 arousals, remaining 49
# Merged 0 arousals, remaining 60
# Merged 0 arousals, remaining 56
# Merged 0 arousals, remaining 63
# Merged 0 arousals, remaining 63
# Merged 0 arousals, remaining 62
# Merged 0 arousals, remaining 81
# Merged 0 arousals, remaining 44
# Merged 0 arousals, remaining 57
# Merged 0 arousals, remaining 45
# Merged 0 arousals, remaining 35
# Merged 0 arousals, remaining 67
# Merged 0 arousals, remaining 93
# Merged 0 arousals, remaining 77
# Merged 0 arousals, remaining 94
# Merged 0 arousals, remaining 36
# Merged 0 arousals, remaining 43
# Merged 0 arousals, remaining 49
# Merged 0 arousals, remaining 110
# Merged 0 arousals, remaining 81
# Merged 0 arousals, remaining 92
# Merged 0 arousals, remaining 64
# Merged 0 arousals, remaining 60
# Merged 0 arousals, remaining 55
# Merged 0 arousals, remaining 89
# Merged 0 arousals, remaining 85
# Merged 0 arousals, remaining 98
# Merged 0 arousals, remaining 35
# Merged 0 arousals, remaining 56
# Merged 0 arousals, remaining 38
# Merged 0 arousals, remaining 22
# Merged 0 arousals, remaining 33
# Merged 0 arousals, remaining 64
# Merged 0 arousals, remaining 45
# Merged 0 arousals, remaining 22
# Merged 0 arousals, remaining 96
# Merged 0 arousals, remaining 20
# Merged 0 arousals, remaining 27
# Merged 0 arousals, remaining 38
# Merged 0 arousals, remaining 50
# Merged 0 arousals, remaining 60
# Merged 0 arousals, remaining 51
# Merged 0 arousals, remaining 58
# Merged 0 arousals, remaining 47
# Merged 0 arousals, remaining 48
# Merged 0 arousals, remaining 51
# Merged 0 arousals, remaining 70
# Merged 0 arousals, remaining 32
# Merged 0 arousals, remaining 24
# Merged 0 arousals, remaining 42
# Merged 0 arousals, remaining 87
# Merged 0 arousals, remaining 48
# Merged 0 arousals, remaining 39
# Merged 0 arousals, remaining 43
# Merged 0 arousals, remaining 41
# Merged 0 arousals, remaining 54
# Merged 0 arousals, remaining 76
# Merged 0 arousals, remaining 58
# Merged 0 arousals, remaining 69
# Merged 0 arousals, remaining 34
# Merged 0 arousals, remaining 36
# Merged 0 arousals, remaining 74
# Merged 0 arousals, remaining 82
# Merged 0 arousals, remaining 36
# Merged 0 arousals, remaining 57
# Merged 0 arousals, remaining 46
# Merged 0 arousals, remaining 43
# Merged 0 arousals, remaining 47
# Merged 0 arousals, remaining 31
# Merged 0 arousals, remaining 42
# Merged 0 arousals, remaining 29
# Merged 0 arousals, remaining 31
# Merged 0 arousals, remaining 69
# Merged 0 arousals, remaining 58
# Merged 0 arousals, remaining 46
# Merged 0 arousals, remaining 37
# Merged 0 arousals, remaining 43
# Merged 0 arousals, remaining 42
# Merged 0 arousals, remaining 75
# Merged 0 arousals, remaining 50
# Merged 0 arousals, remaining 73
# Merged 0 arousals, remaining 49
# Merged 0 arousals, remaining 67
# Merged 0 arousals, remaining 43
# Merged 0 arousals, remaining 31
# Merged 0 arousals, remaining 58
# Merged 0 arousals, remaining 63
# Merged 0 arousals, remaining 22
# Merged 0 arousals, remaining 40
# Processing 4 3 15
# Merged 0 arousals, remaining 89
# Merged 0 arousals, remaining 126
# Merged 0 arousals, remaining 85
# Merged 0 arousals, remaining 127
# Merged 0 arousals, remaining 173
# Merged 0 arousals, remaining 132
# Merged 0 arousals, remaining 106
# Merged 0 arousals, remaining 82
# Merged 0 arousals, remaining 95
# Merged 0 arousals, remaining 109
# Merged 0 arousals, remaining 157
# Merged 0 arousals, remaining 160
# Merged 0 arousals, remaining 80
# Merged 0 arousals, remaining 101
# Merged 0 arousals, remaining 163
# Merged 0 arousals, remaining 44
# Merged 0 arousals, remaining 263
# Merged 0 arousals, remaining 147
# Merged 0 arousals, remaining 135
# Merged 0 arousals, remaining 185
# Merged 0 arousals, remaining 203
# Merged 0 arousals, remaining 87
# Merged 0 arousals, remaining 169
# Merged 0 arousals, remaining 181
# Merged 0 arousals, remaining 129
# Merged 0 arousals, remaining 88
# Merged 0 arousals, remaining 70
# Merged 0 arousals, remaining 100
# Merged 0 arousals, remaining 101
# Merged 0 arousals, remaining 103
# Merged 0 arousals, remaining 84
# Merged 0 arousals, remaining 97
# Merged 0 arousals, remaining 130
# Merged 0 arousals, remaining 104
# Merged 0 arousals, remaining 92
# Merged 0 arousals, remaining 69
# Merged 0 arousals, remaining 74
# Merged 0 arousals, remaining 105
# Merged 0 arousals, remaining 165
# Merged 0 arousals, remaining 103
# Merged 0 arousals, remaining 153
# Merged 0 arousals, remaining 55
# Merged 0 arousals, remaining 71
# Merged 0 arousals, remaining 88
# Merged 0 arousals, remaining 214
# Merged 0 arousals, remaining 132
# Merged 0 arousals, remaining 148
# Merged 0 arousals, remaining 107
# Merged 0 arousals, remaining 104
# Merged 0 arousals, remaining 102
# Merged 0 arousals, remaining 168
# Merged 0 arousals, remaining 149
# Merged 0 arousals, remaining 166
# Merged 0 arousals, remaining 50
# Merged 0 arousals, remaining 88
# Merged 0 arousals, remaining 58
# Merged 0 arousals, remaining 37
# Merged 0 arousals, remaining 54
# Merged 0 arousals, remaining 89
# Merged 0 arousals, remaining 54
# Merged 0 arousals, remaining 27
# Merged 0 arousals, remaining 143
# Merged 0 arousals, remaining 29
# Merged 0 arousals, remaining 61
# Merged 0 arousals, remaining 52
# Merged 0 arousals, remaining 71
# Merged 0 arousals, remaining 118
# Merged 0 arousals, remaining 80
# Merged 0 arousals, remaining 82
# Merged 0 arousals, remaining 67
# Merged 0 arousals, remaining 73
# Merged 0 arousals, remaining 80
# Merged 0 arousals, remaining 136
# Merged 0 arousals, remaining 53
# Merged 0 arousals, remaining 34
# Merged 0 arousals, remaining 71
# Merged 0 arousals, remaining 128
# Merged 0 arousals, remaining 85
# Merged 0 arousals, remaining 61
# Merged 0 arousals, remaining 81
# Merged 0 arousals, remaining 61
# Merged 0 arousals, remaining 87
# Merged 0 arousals, remaining 119
# Merged 0 arousals, remaining 92
# Merged 0 arousals, remaining 136
# Merged 0 arousals, remaining 47
# Merged 0 arousals, remaining 48
# Merged 0 arousals, remaining 124
# Merged 0 arousals, remaining 104
# Merged 0 arousals, remaining 60
# Merged 0 arousals, remaining 90
# Merged 0 arousals, remaining 75
# Merged 0 arousals, remaining 54
# Merged 0 arousals, remaining 69
# Merged 0 arousals, remaining 43
# Merged 0 arousals, remaining 59
# Merged 0 arousals, remaining 46
# Merged 0 arousals, remaining 41
# Merged 0 arousals, remaining 115
# Merged 0 arousals, remaining 103
# Merged 0 arousals, remaining 83
# Merged 0 arousals, remaining 73
# Merged 0 arousals, remaining 59
# Merged 0 arousals, remaining 66
# Merged 0 arousals, remaining 127
# Merged 0 arousals, remaining 82
# Merged 0 arousals, remaining 126
# Merged 0 arousals, remaining 77
# Merged 0 arousals, remaining 104
# Merged 0 arousals, remaining 87
# Merged 0 arousals, remaining 50
# Merged 0 arousals, remaining 89
# Merged 0 arousals, remaining 112
# Merged 0 arousals, remaining 32
# Merged 0 arousals, remaining 58
# Processing 8 3 15
# Merged 0 arousals, remaining 163
# Merged 0 arousals, remaining 215
# Merged 0 arousals, remaining 136
# Merged 0 arousals, remaining 171
# Merged 0 arousals, remaining 346
# Merged 0 arousals, remaining 216
# Merged 0 arousals, remaining 169
# Merged 0 arousals, remaining 154
# Merged 0 arousals, remaining 165
# Merged 0 arousals, remaining 215
# Merged 0 arousals, remaining 245
# Merged 0 arousals, remaining 269
# Merged 0 arousals, remaining 149
# Merged 0 arousals, remaining 184
# Merged 0 arousals, remaining 272
# Merged 0 arousals, remaining 85
# Merged 0 arousals, remaining 468
# Merged 0 arousals, remaining 274
# Merged 0 arousals, remaining 226
# Merged 0 arousals, remaining 304
# Merged 0 arousals, remaining 310
# Merged 0 arousals, remaining 156
# Merged 0 arousals, remaining 299
# Merged 0 arousals, remaining 281
# Merged 0 arousals, remaining 264
# Merged 0 arousals, remaining 140
# Merged 0 arousals, remaining 116
# Merged 0 arousals, remaining 172
# Merged 0 arousals, remaining 228
# Merged 0 arousals, remaining 207
# Merged 0 arousals, remaining 118
# Merged 0 arousals, remaining 157
# Merged 0 arousals, remaining 259
# Merged 0 arousals, remaining 216
# Merged 0 arousals, remaining 178
# Merged 0 arousals, remaining 110
# Merged 0 arousals, remaining 138
# Merged 0 arousals, remaining 178
# Merged 0 arousals, remaining 283
# Merged 0 arousals, remaining 157
# Merged 0 arousals, remaining 272
# Merged 0 arousals, remaining 106
# Merged 0 arousals, remaining 151
# Merged 0 arousals, remaining 152
# Merged 0 arousals, remaining 395
# Merged 0 arousals, remaining 214
# Merged 0 arousals, remaining 226
# Merged 0 arousals, remaining 195
# Merged 0 arousals, remaining 158
# Merged 0 arousals, remaining 174
# Merged 0 arousals, remaining 245
# Merged 0 arousals, remaining 227
# Merged 0 arousals, remaining 291
# Merged 0 arousals, remaining 84
# Merged 0 arousals, remaining 147
# Merged 0 arousals, remaining 92
# Merged 0 arousals, remaining 51
# Merged 0 arousals, remaining 96
# Merged 0 arousals, remaining 134
# Merged 0 arousals, remaining 74
# Merged 0 arousals, remaining 42
# Merged 0 arousals, remaining 256
# Merged 0 arousals, remaining 42
# Merged 0 arousals, remaining 100
# Merged 0 arousals, remaining 83
# Merged 0 arousals, remaining 116
# Merged 0 arousals, remaining 214
# Merged 0 arousals, remaining 123
# Merged 0 arousals, remaining 117
# Merged 0 arousals, remaining 122
# Merged 0 arousals, remaining 114
# Merged 0 arousals, remaining 130
# Merged 0 arousals, remaining 302
# Merged 0 arousals, remaining 78
# Merged 0 arousals, remaining 56
# Merged 0 arousals, remaining 137
# Merged 0 arousals, remaining 176
# Merged 0 arousals, remaining 151
# Merged 0 arousals, remaining 101
# Merged 0 arousals, remaining 129
# Merged 0 arousals, remaining 104
# Merged 0 arousals, remaining 168
# Merged 0 arousals, remaining 169
# Merged 0 arousals, remaining 151
# Merged 0 arousals, remaining 270
# Merged 0 arousals, remaining 67
# Merged 0 arousals, remaining 69
# Merged 0 arousals, remaining 234
# Merged 0 arousals, remaining 127
# Merged 0 arousals, remaining 112
# Merged 0 arousals, remaining 137
# Merged 0 arousals, remaining 140
# Merged 0 arousals, remaining 102
# Merged 0 arousals, remaining 97
# Merged 0 arousals, remaining 60
# Merged 0 arousals, remaining 89
# Merged 0 arousals, remaining 89
# Merged 0 arousals, remaining 60
# Merged 0 arousals, remaining 204
# Merged 0 arousals, remaining 179
# Merged 0 arousals, remaining 140
# Merged 0 arousals, remaining 109
# Merged 0 arousals, remaining 89
# Merged 0 arousals, remaining 139
# Merged 0 arousals, remaining 184
# Merged 0 arousals, remaining 137
# Merged 0 arousals, remaining 221
# Merged 0 arousals, remaining 123
# Merged 0 arousals, remaining 201
# Merged 0 arousals, remaining 162
# Merged 0 arousals, remaining 81
# Merged 0 arousals, remaining 142
# Merged 0 arousals, remaining 192
# Merged 0 arousals, remaining 64
# Merged 0 arousals, remaining 100
# Processing 16 3 15
# Merged 0 arousals, remaining 312
# Merged 0 arousals, remaining 486
# Merged 0 arousals, remaining 263
# Merged 0 arousals, remaining 343
# Merged 0 arousals, remaining 702
# Merged 0 arousals, remaining 428
# Merged 0 arousals, remaining 343
# Merged 0 arousals, remaining 341
# Merged 0 arousals, remaining 332
# Merged 0 arousals, remaining 531
# Merged 0 arousals, remaining 509
# Merged 0 arousals, remaining 513
# Merged 0 arousals, remaining 274
# Merged 0 arousals, remaining 451
# Merged 0 arousals, remaining 568
# Merged 0 arousals, remaining 186
# Merged 0 arousals, remaining 931
# Merged 0 arousals, remaining 604
# Merged 0 arousals, remaining 424
# Merged 0 arousals, remaining 515
# Merged 0 arousals, remaining 578
# Merged 0 arousals, remaining 312
# Merged 0 arousals, remaining 552
# Merged 0 arousals, remaining 551
# Merged 0 arousals, remaining 579
# Merged 0 arousals, remaining 286
# Merged 0 arousals, remaining 220
# Merged 0 arousals, remaining 364
# Merged 0 arousals, remaining 458
# Merged 0 arousals, remaining 411
# Merged 0 arousals, remaining 225
# Merged 0 arousals, remaining 283
# Merged 0 arousals, remaining 518
# Merged 0 arousals, remaining 487
# Merged 0 arousals, remaining 412
# Merged 0 arousals, remaining 224
# Merged 0 arousals, remaining 333
# Merged 0 arousals, remaining 339
# Merged 0 arousals, remaining 545
# Merged 0 arousals, remaining 260
# Merged 0 arousals, remaining 593
# Merged 0 arousals, remaining 198
# Merged 0 arousals, remaining 400
# Merged 0 arousals, remaining 329
# Merged 0 arousals, remaining 858
# Merged 0 arousals, remaining 370
# Merged 0 arousals, remaining 480
# Merged 0 arousals, remaining 391
# Merged 0 arousals, remaining 323
# Merged 0 arousals, remaining 344
# Merged 0 arousals, remaining 475
# Merged 0 arousals, remaining 461
# Merged 0 arousals, remaining 462
# Merged 0 arousals, remaining 181
# Merged 0 arousals, remaining 266
# Merged 0 arousals, remaining 205
# Merged 0 arousals, remaining 97
# Merged 0 arousals, remaining 162
# Merged 0 arousals, remaining 244
# Merged 0 arousals, remaining 130
# Merged 0 arousals, remaining 83
# Merged 0 arousals, remaining 434
# Merged 0 arousals, remaining 68
# Merged 0 arousals, remaining 264
# Merged 0 arousals, remaining 185
# Merged 0 arousals, remaining 215
# Merged 0 arousals, remaining 500
# Merged 0 arousals, remaining 236
# Merged 0 arousals, remaining 222
# Merged 0 arousals, remaining 225
# Merged 0 arousals, remaining 206
# Merged 0 arousals, remaining 234
# Merged 0 arousals, remaining 638
# Merged 0 arousals, remaining 151
# Merged 0 arousals, remaining 100
# Merged 0 arousals, remaining 295
# Merged 0 arousals, remaining 311
# Merged 0 arousals, remaining 275
# Merged 0 arousals, remaining 257
# Merged 0 arousals, remaining 246
# Merged 0 arousals, remaining 200
# Merged 0 arousals, remaining 339
# Merged 0 arousals, remaining 287
# Merged 0 arousals, remaining 333
# Merged 0 arousals, remaining 507
# Merged 0 arousals, remaining 127
# Merged 0 arousals, remaining 146
# Merged 0 arousals, remaining 502
# Merged 0 arousals, remaining 189
# Merged 0 arousals, remaining 236
# Merged 0 arousals, remaining 259
# Merged 0 arousals, remaining 284
# Merged 0 arousals, remaining 268
# Merged 0 arousals, remaining 163
# Merged 0 arousals, remaining 104
# Merged 0 arousals, remaining 144
# Merged 0 arousals, remaining 209
# Merged 0 arousals, remaining 96
# Merged 0 arousals, remaining 408
# Merged 0 arousals, remaining 319
# Merged 0 arousals, remaining 294
# Merged 0 arousals, remaining 174
# Merged 0 arousals, remaining 186
# Merged 0 arousals, remaining 292
# Merged 0 arousals, remaining 315
# Merged 0 arousals, remaining 290
# Merged 0 arousals, remaining 473
# Merged 0 arousals, remaining 216
# Merged 0 arousals, remaining 484
# Merged 0 arousals, remaining 347
# Merged 0 arousals, remaining 160
# Merged 0 arousals, remaining 320
# Merged 0 arousals, remaining 366
# Merged 0 arousals, remaining 141
# Merged 0 arousals, remaining 207
# Processing 32 3 15
# Merged 29 arousals, remaining 912
# Merged 136 arousals, remaining 1746
# Merged 50 arousals, remaining 813
# Merged 56 arousals, remaining 1056
# Merged 61 arousals, remaining 1914
# Merged 48 arousals, remaining 1252
# Merged 44 arousals, remaining 1045
# Merged 82 arousals, remaining 1151
# Merged 60 arousals, remaining 1035
# Merged 196 arousals, remaining 1520
# Merged 163 arousals, remaining 1621
# Merged 114 arousals, remaining 1640
# Merged 42 arousals, remaining 871
# Merged 187 arousals, remaining 1813
# Merged 131 arousals, remaining 1666
# Merged 98 arousals, remaining 904
# Merged 250 arousals, remaining 2756
# Merged 153 arousals, remaining 1764
# Merged 73 arousals, remaining 1233
# Merged 103 arousals, remaining 1365
# Merged 79 arousals, remaining 1671
# Merged 111 arousals, remaining 1046
# Merged 104 arousals, remaining 1572
# Merged 79 arousals, remaining 1758
# Merged 86 arousals, remaining 1615
# Merged 81 arousals, remaining 929
# Merged 101 arousals, remaining 947
# Merged 72 arousals, remaining 1103
# Merged 133 arousals, remaining 1563
# Merged 97 arousals, remaining 1225
# Merged 27 arousals, remaining 722
# Merged 98 arousals, remaining 946
# Merged 129 arousals, remaining 1571
# Merged 84 arousals, remaining 1569
# Merged 131 arousals, remaining 1385
# Merged 52 arousals, remaining 773
# Merged 264 arousals, remaining 1515
# Merged 93 arousals, remaining 1071
# Merged 99 arousals, remaining 1610
# Merged 50 arousals, remaining 728
# Merged 69 arousals, remaining 1709
# Merged 47 arousals, remaining 599
# Merged 113 arousals, remaining 1184
# Merged 48 arousals, remaining 1106
# Merged 131 arousals, remaining 2471
# Merged 77 arousals, remaining 1128
# Merged 88 arousals, remaining 1537
# Merged 83 arousals, remaining 1169
# Merged 41 arousals, remaining 944
# Merged 73 arousals, remaining 1161
# Merged 103 arousals, remaining 1155
# Merged 123 arousals, remaining 1407
# Merged 87 arousals, remaining 1334
# Merged 35 arousals, remaining 582
# Merged 34 arousals, remaining 830
# Merged 13 arousals, remaining 756
# Merged 7 arousals, remaining 329
# Merged 13 arousals, remaining 473
# Merged 38 arousals, remaining 695
# Merged 44 arousals, remaining 491
# Merged 10 arousals, remaining 284
# Merged 49 arousals, remaining 1166
# Merged 9 arousals, remaining 206
# Merged 21 arousals, remaining 1211
# Merged 78 arousals, remaining 590
# Merged 18 arousals, remaining 685
# Merged 173 arousals, remaining 1899
# Merged 20 arousals, remaining 652
# Merged 31 arousals, remaining 698
# Merged 41 arousals, remaining 731
# Merged 24 arousals, remaining 622
# Merged 50 arousals, remaining 713
# Merged 202 arousals, remaining 1792
# Merged 18 arousals, remaining 402
# Merged 8 arousals, remaining 331
# Merged 26 arousals, remaining 772
# Merged 50 arousals, remaining 1002
# Merged 34 arousals, remaining 827
# Merged 62 arousals, remaining 960
# Merged 35 arousals, remaining 681
# Merged 34 arousals, remaining 602
# Merged 56 arousals, remaining 1043
# Merged 40 arousals, remaining 759
# Merged 42 arousals, remaining 1096
# Merged 150 arousals, remaining 1531
# Merged 95 arousals, remaining 476
# Merged 25 arousals, remaining 476
# Merged 69 arousals, remaining 1357
# Merged 45 arousals, remaining 537
# Merged 37 arousals, remaining 871
# Merged 33 arousals, remaining 786
# Merged 53 arousals, remaining 786
# Merged 92 arousals, remaining 1052
# Merged 31 arousals, remaining 443
# Merged 13 arousals, remaining 411
# Merged 17 arousals, remaining 469
# Merged 91 arousals, remaining 774
# Merged 13 arousals, remaining 303
# Merged 129 arousals, remaining 1386
# Merged 69 arousals, remaining 927
# Merged 64 arousals, remaining 803
# Merged 30 arousals, remaining 510
# Merged 75 arousals, remaining 597
# Merged 103 arousals, remaining 1065
# Merged 101 arousals, remaining 1155
# Merged 83 arousals, remaining 946
# Merged 115 arousals, remaining 1626
# Merged 15 arousals, remaining 614
# Merged 112 arousals, remaining 1434
# Merged 92 arousals, remaining 1036
# Merged 22 arousals, remaining 506
# Merged 108 arousals, remaining 1135
# Merged 51 arousals, remaining 1029
# Merged 114 arousals, remaining 672
# Merged 78 arousals, remaining 772
# Processing 64 3 15
# Merged 128 arousals, remaining 1562
# Merged 423 arousals, remaining 2931
# Merged 199 arousals, remaining 1542
# Merged 229 arousals, remaining 2060
# Merged 258 arousals, remaining 3344
# Merged 309 arousals, remaining 2443
# Merged 140 arousals, remaining 1900
# Merged 480 arousals, remaining 1998
# Merged 217 arousals, remaining 1922
# Merged 526 arousals, remaining 2493
# Merged 559 arousals, remaining 2873
# Merged 489 arousals, remaining 2949
# Merged 185 arousals, remaining 1771
# Merged 678 arousals, remaining 3253
# Merged 553 arousals, remaining 2861
# Merged 724 arousals, remaining 1672
# Merged 760 arousals, remaining 4669
# Merged 421 arousals, remaining 2890
# Merged 307 arousals, remaining 2177
# Merged 452 arousals, remaining 2395
# Merged 448 arousals, remaining 3049
# Merged 417 arousals, remaining 2027
# Merged 470 arousals, remaining 2793
# Merged 214 arousals, remaining 3248
# Merged 272 arousals, remaining 2664
# Merged 336 arousals, remaining 1744
# Merged 472 arousals, remaining 1764
# Merged 346 arousals, remaining 2035
# Merged 395 arousals, remaining 2489
# Merged 337 arousals, remaining 2118
# Merged 137 arousals, remaining 1330
# Merged 478 arousals, remaining 1809
# Merged 406 arousals, remaining 2744
# Merged 201 arousals, remaining 2559
# Merged 395 arousals, remaining 2305
# Merged 208 arousals, remaining 1551
# Merged 1018 arousals, remaining 2545
# Merged 289 arousals, remaining 1839
# Merged 407 arousals, remaining 2866
# Merged 187 arousals, remaining 1407
# Merged 347 arousals, remaining 2957
# Merged 255 arousals, remaining 1159
# Merged 371 arousals, remaining 2016
# Merged 141 arousals, remaining 2231
# Merged 487 arousals, remaining 3982
# Merged 203 arousals, remaining 2082
# Merged 351 arousals, remaining 2955
# Merged 305 arousals, remaining 2058
# Merged 204 arousals, remaining 1687
# Merged 380 arousals, remaining 2102
# Merged 321 arousals, remaining 2005
# Merged 463 arousals, remaining 2502
# Merged 383 arousals, remaining 2268
# Merged 125 arousals, remaining 1014
# Merged 141 arousals, remaining 1554
# Merged 64 arousals, remaining 1534
# Merged 30 arousals, remaining 725
# Merged 67 arousals, remaining 1068
# Merged 110 arousals, remaining 1301
# Merged 188 arousals, remaining 986
# Merged 52 arousals, remaining 643
# Merged 230 arousals, remaining 2213
# Merged 31 arousals, remaining 430
# Merged 77 arousals, remaining 2335
# Merged 231 arousals, remaining 1088
# Merged 94 arousals, remaining 1377
# Merged 558 arousals, remaining 3247
# Merged 95 arousals, remaining 1264
# Merged 188 arousals, remaining 1465
# Merged 146 arousals, remaining 1271
# Merged 106 arousals, remaining 1195
# Merged 254 arousals, remaining 1376
# Merged 523 arousals, remaining 3092
# Merged 81 arousals, remaining 824
# Merged 24 arousals, remaining 767
# Merged 100 arousals, remaining 1429
# Merged 199 arousals, remaining 1774
# Merged 123 arousals, remaining 1546
# Merged 263 arousals, remaining 1802
# Merged 109 arousals, remaining 1336
# Merged 132 arousals, remaining 1225
# Merged 195 arousals, remaining 2073
# Merged 169 arousals, remaining 1409
# Merged 244 arousals, remaining 2127
# Merged 445 arousals, remaining 2555
# Merged 261 arousals, remaining 861
# Merged 126 arousals, remaining 901
# Merged 180 arousals, remaining 2460
# Merged 117 arousals, remaining 1036
# Merged 221 arousals, remaining 1725
# Merged 147 arousals, remaining 1587
# Merged 206 arousals, remaining 1391
# Merged 291 arousals, remaining 1775
# Merged 108 arousals, remaining 852
# Merged 117 arousals, remaining 829
# Merged 64 arousals, remaining 1007
# Merged 322 arousals, remaining 1528
# Merged 59 arousals, remaining 627
# Merged 399 arousals, remaining 2560
# Merged 329 arousals, remaining 1893
# Merged 201 arousals, remaining 1374
# Merged 122 arousals, remaining 1058
# Merged 296 arousals, remaining 1162
# Merged 416 arousals, remaining 1822
# Merged 421 arousals, remaining 2081
# Merged 287 arousals, remaining 1679
# Merged 399 arousals, remaining 2860
# Merged 75 arousals, remaining 1289
# Merged 302 arousals, remaining 2591
# Merged 300 arousals, remaining 1674
# Merged 138 arousals, remaining 962
# Merged 331 arousals, remaining 2118
# Merged 206 arousals, remaining 1989
# Merged 583 arousals, remaining 1234
# Merged 238 arousals, remaining 1455
# Processing 128 3 15
# Merged 233 arousals, remaining 2460
# Merged 669 arousals, remaining 4630
# Merged 488 arousals, remaining 2631
# Merged 558 arousals, remaining 3654
# Merged 525 arousals, remaining 5468
# Merged 846 arousals, remaining 4031
# Merged 298 arousals, remaining 3312
# Merged 846 arousals, remaining 2889
# Merged 391 arousals, remaining 3413
# Merged 892 arousals, remaining 3656
# Merged 897 arousals, remaining 4639
# Merged 813 arousals, remaining 4901
# Merged 341 arousals, remaining 3219
# Merged 1016 arousals, remaining 5181
# Merged 1013 arousals, remaining 4447
# Merged 1316 arousals, remaining 2584
# Merged 1237 arousals, remaining 7146
# Merged 651 arousals, remaining 4500
# Merged 589 arousals, remaining 3535
# Merged 792 arousals, remaining 3802
# Merged 845 arousals, remaining 4933
# Merged 826 arousals, remaining 3290
# Merged 856 arousals, remaining 4783
# Merged 397 arousals, remaining 5672
# Merged 394 arousals, remaining 4218
# Merged 610 arousals, remaining 2874
# Merged 785 arousals, remaining 2758
# Merged 617 arousals, remaining 3215
# Merged 596 arousals, remaining 3902
# Merged 643 arousals, remaining 3369
# Merged 267 arousals, remaining 2357
# Merged 858 arousals, remaining 2893
# Merged 748 arousals, remaining 4333
# Merged 273 arousals, remaining 3462
# Merged 531 arousals, remaining 3622
# Merged 433 arousals, remaining 2750
# Merged 1510 arousals, remaining 3657
# Merged 492 arousals, remaining 2923
# Merged 707 arousals, remaining 4538
# Merged 394 arousals, remaining 2478
# Merged 706 arousals, remaining 4703
# Merged 556 arousals, remaining 1808
# Merged 682 arousals, remaining 3328
# Merged 299 arousals, remaining 4277
# Merged 869 arousals, remaining 6031
# Merged 364 arousals, remaining 3420
# Merged 630 arousals, remaining 5019
# Merged 551 arousals, remaining 3553
# Merged 391 arousals, remaining 2773
# Merged 734 arousals, remaining 3280
# Merged 696 arousals, remaining 3163
# Merged 863 arousals, remaining 3929
# Merged 639 arousals, remaining 3597
# Merged 199 arousals, remaining 1691
# Merged 254 arousals, remaining 2859
# Merged 143 arousals, remaining 2671
# Merged 85 arousals, remaining 1484
# Merged 153 arousals, remaining 2108
# Merged 217 arousals, remaining 2279
# Merged 286 arousals, remaining 1874
# Merged 83 arousals, remaining 1237
# Merged 562 arousals, remaining 3818
# Merged 79 arousals, remaining 867
# Merged 182 arousals, remaining 4145
# Merged 378 arousals, remaining 1758
# Merged 247 arousals, remaining 2417
# Merged 806 arousals, remaining 5004
# Merged 189 arousals, remaining 2217
# Merged 388 arousals, remaining 2616
# Merged 265 arousals, remaining 2133
# Merged 217 arousals, remaining 2025
# Merged 531 arousals, remaining 2352
# Merged 763 arousals, remaining 4881
# Merged 132 arousals, remaining 1528
# Merged 66 arousals, remaining 1662
# Merged 207 arousals, remaining 2621
# Merged 387 arousals, remaining 2885
# Merged 213 arousals, remaining 2735
# Merged 424 arousals, remaining 3181
# Merged 190 arousals, remaining 2457
# Merged 280 arousals, remaining 2328
# Merged 446 arousals, remaining 3928
# Merged 386 arousals, remaining 2363
# Merged 506 arousals, remaining 3689
# Merged 712 arousals, remaining 3956
# Merged 388 arousals, remaining 1410
# Merged 222 arousals, remaining 1650
# Merged 387 arousals, remaining 4134
# Merged 227 arousals, remaining 1978
# Merged 380 arousals, remaining 2950
# Merged 340 arousals, remaining 3034
# Merged 335 arousals, remaining 2254
# Merged 487 arousals, remaining 2598
# Merged 229 arousals, remaining 1600
# Merged 167 arousals, remaining 1577
# Merged 142 arousals, remaining 2096
# Merged 542 arousals, remaining 2625
# Merged 121 arousals, remaining 1182
# Merged 615 arousals, remaining 4304
# Merged 770 arousals, remaining 3307
# Merged 333 arousals, remaining 2201
# Merged 242 arousals, remaining 1925
# Merged 446 arousals, remaining 1961
# Merged 673 arousals, remaining 2820
# Merged 714 arousals, remaining 3439
# Merged 502 arousals, remaining 2776
# Merged 674 arousals, remaining 4622
# Merged 192 arousals, remaining 2469
# Merged 474 arousals, remaining 4221
# Merged 491 arousals, remaining 2504
# Merged 228 arousals, remaining 1797
# Merged 452 arousals, remaining 3748
# Merged 422 arousals, remaining 3608
# Merged 945 arousals, remaining 1896
# Merged 333 arousals, remaining 2735
# Processing 256 3 15
# Merged 436 arousals, remaining 3654
# Merged 1114 arousals, remaining 6691
# Merged 858 arousals, remaining 4244
# Merged 1016 arousals, remaining 6243
# Merged 1017 arousals, remaining 8339
# Merged 1698 arousals, remaining 5964
# Merged 518 arousals, remaining 5226
# Merged 1362 arousals, remaining 3873
# Merged 714 arousals, remaining 5566
# Merged 1347 arousals, remaining 5327
# Merged 1409 arousals, remaining 6800
# Merged 1193 arousals, remaining 7418
# Merged 548 arousals, remaining 5506
# Merged 1564 arousals, remaining 7604
# Merged 1766 arousals, remaining 6184
# Merged 2149 arousals, remaining 3933
# Merged 1843 arousals, remaining 10304
# Merged 1064 arousals, remaining 6587
# Merged 979 arousals, remaining 5433
# Merged 1268 arousals, remaining 5703
# Merged 1459 arousals, remaining 7471
# Merged 1358 arousals, remaining 5068
# Merged 1441 arousals, remaining 7692
# Merged 858 arousals, remaining 9122
# Merged 697 arousals, remaining 6184
# Merged 929 arousals, remaining 4557
# Merged 1109 arousals, remaining 4135
# Merged 1022 arousals, remaining 4650
# Merged 948 arousals, remaining 5764
# Merged 1087 arousals, remaining 4779
# Merged 521 arousals, remaining 3729
# Merged 1307 arousals, remaining 4249
# Merged 1459 arousals, remaining 6717
# Merged 431 arousals, remaining 4073
# Merged 757 arousals, remaining 5097
# Merged 762 arousals, remaining 4518
# Merged 2044 arousals, remaining 4964
# Merged 772 arousals, remaining 4247
# Merged 1191 arousals, remaining 6595
# Merged 650 arousals, remaining 4346
# Merged 1170 arousals, remaining 7062
# Merged 893 arousals, remaining 2474
# Merged 1183 arousals, remaining 5080
# Merged 542 arousals, remaining 7315
# Merged 1385 arousals, remaining 8889
# Merged 626 arousals, remaining 5373
# Merged 1072 arousals, remaining 7620
# Merged 900 arousals, remaining 5757
# Merged 688 arousals, remaining 4120
# Merged 1278 arousals, remaining 4859
# Merged 1217 arousals, remaining 4559
# Merged 1400 arousals, remaining 5716
# Merged 1055 arousals, remaining 5509
# Merged 283 arousals, remaining 2599
# Merged 456 arousals, remaining 4931
# Merged 247 arousals, remaining 4428
# Merged 143 arousals, remaining 2801
# Merged 271 arousals, remaining 3722
# Merged 336 arousals, remaining 3835
# Merged 421 arousals, remaining 3333
# Merged 129 arousals, remaining 2211
# Merged 1075 arousals, remaining 5915
# Merged 118 arousals, remaining 1557
# Merged 343 arousals, remaining 6414
# Merged 534 arousals, remaining 2811
# Merged 385 arousals, remaining 4103
# Merged 1152 arousals, remaining 7508
# Merged 327 arousals, remaining 3635
# Merged 690 arousals, remaining 4345
# Merged 392 arousals, remaining 3424
# Merged 388 arousals, remaining 3278
# Merged 968 arousals, remaining 3727
# Merged 1213 arousals, remaining 7105
# Merged 205 arousals, remaining 2735
# Merged 109 arousals, remaining 3131
# Merged 381 arousals, remaining 4400
# Merged 645 arousals, remaining 4624
# Merged 373 arousals, remaining 4516
# Merged 660 arousals, remaining 5115
# Merged 359 arousals, remaining 3944
# Merged 465 arousals, remaining 3921
# Merged 804 arousals, remaining 6398
# Merged 691 arousals, remaining 3906
# Merged 877 arousals, remaining 5708
# Merged 1142 arousals, remaining 6050
# Merged 559 arousals, remaining 2141
# Merged 322 arousals, remaining 2908
# Merged 723 arousals, remaining 6434
# Merged 423 arousals, remaining 3400
# Merged 576 arousals, remaining 4631
# Merged 557 arousals, remaining 5142
# Merged 501 arousals, remaining 3454
# Merged 774 arousals, remaining 3797
# Merged 362 arousals, remaining 2541
# Merged 286 arousals, remaining 2737
# Merged 266 arousals, remaining 3974
# Merged 894 arousals, remaining 4253
# Merged 221 arousals, remaining 2092
# Merged 969 arousals, remaining 6568
# Merged 1374 arousals, remaining 5316
# Merged 549 arousals, remaining 3422
# Merged 382 arousals, remaining 3313
# Merged 703 arousals, remaining 2978
# Merged 1048 arousals, remaining 4191
# Merged 1146 arousals, remaining 5349
# Merged 852 arousals, remaining 4205
# Merged 1086 arousals, remaining 7077
# Merged 424 arousals, remaining 4266
# Merged 898 arousals, remaining 6541
# Merged 781 arousals, remaining 3489
# Merged 396 arousals, remaining 3098
# Merged 756 arousals, remaining 6113
# Merged 826 arousals, remaining 5880
# Merged 1367 arousals, remaining 2806
# Merged 516 arousals, remaining 4666
# Processing 384 3 15
# Merged 627 arousals, remaining 4432
# Merged 1433 arousals, remaining 7954
# Merged 1172 arousals, remaining 5198
# Merged 1465 arousals, remaining 7969
# Merged 1501 arousals, remaining 10278
# Merged 2442 arousals, remaining 7133
# Merged 729 arousals, remaining 6273
# Merged 2646 arousals, remaining 4444
# Merged 1056 arousals, remaining 6905
# Merged 1772 arousals, remaining 6288
# Merged 1802 arousals, remaining 8012
# Merged 1627 arousals, remaining 8745
# Merged 785 arousals, remaining 7009
# Merged 2061 arousals, remaining 9235
# Merged 2496 arousals, remaining 7328
# Merged 2915 arousals, remaining 4822
# Merged 2430 arousals, remaining 12024
# Merged 1363 arousals, remaining 7750
# Merged 1576 arousals, remaining 6443
# Merged 1771 arousals, remaining 6839
# Merged 1927 arousals, remaining 9023
# Merged 1790 arousals, remaining 6118
# Merged 1846 arousals, remaining 9515
# Merged 1518 arousals, remaining 11300
# Merged 934 arousals, remaining 7323
# Merged 1273 arousals, remaining 5604
# Merged 1459 arousals, remaining 4914
# Merged 1373 arousals, remaining 5446
# Merged 1244 arousals, remaining 6801
# Merged 1489 arousals, remaining 5631
# Merged 743 arousals, remaining 4520
# Merged 1669 arousals, remaining 5032
# Merged 2278 arousals, remaining 8573
# Merged 545 arousals, remaining 4523
# Merged 944 arousals, remaining 5935
# Merged 1087 arousals, remaining 5542
# Merged 2510 arousals, remaining 5555
# Merged 1035 arousals, remaining 4920
# Merged 1695 arousals, remaining 7732
# Merged 879 arousals, remaining 5434
# Merged 1609 arousals, remaining 8513
# Merged 1233 arousals, remaining 2814
# Merged 1735 arousals, remaining 6188
# Merged 817 arousals, remaining 9154
# Merged 2012 arousals, remaining 10441
# Merged 843 arousals, remaining 6522
# Merged 1475 arousals, remaining 9095
# Merged 1266 arousals, remaining 7488
# Merged 962 arousals, remaining 5059
# Merged 1728 arousals, remaining 5812
# Merged 1909 arousals, remaining 5629
# Merged 1855 arousals, remaining 6679
# Merged 1368 arousals, remaining 6671
# Merged 384 arousals, remaining 3078
# Merged 669 arousals, remaining 6165
# Merged 345 arousals, remaining 5491
# Merged 220 arousals, remaining 3677
# Merged 326 arousals, remaining 4709
# Merged 460 arousals, remaining 4679
# Merged 494 arousals, remaining 4055
# Merged 176 arousals, remaining 2698
# Merged 1513 arousals, remaining 7039
# Merged 151 arousals, remaining 1950
# Merged 482 arousals, remaining 7649
# Merged 705 arousals, remaining 3421
# Merged 578 arousals, remaining 5118
# Merged 1488 arousals, remaining 9029
# Merged 471 arousals, remaining 4423
# Merged 946 arousals, remaining 5363
# Merged 535 arousals, remaining 4206
# Merged 606 arousals, remaining 4103
# Merged 1346 arousals, remaining 4790
# Merged 1548 arousals, remaining 8278
# Merged 271 arousals, remaining 3469
# Merged 160 arousals, remaining 4036
# Merged 520 arousals, remaining 5560
# Merged 834 arousals, remaining 5570
# Merged 494 arousals, remaining 5570
# Merged 862 arousals, remaining 6363
# Merged 484 arousals, remaining 4876
# Merged 717 arousals, remaining 4895
# Merged 1130 arousals, remaining 8078
# Merged 884 arousals, remaining 4858
# Merged 1327 arousals, remaining 6942
# Merged 1390 arousals, remaining 7270
# Merged 742 arousals, remaining 2549
# Merged 484 arousals, remaining 3585
# Merged 1010 arousals, remaining 7570
# Merged 586 arousals, remaining 4336
# Merged 779 arousals, remaining 5562
# Merged 793 arousals, remaining 6454
# Merged 644 arousals, remaining 4189
# Merged 1066 arousals, remaining 4423
# Merged 451 arousals, remaining 3055
# Merged 361 arousals, remaining 3488
# Merged 394 arousals, remaining 5132
# Merged 1564 arousals, remaining 5354
# Merged 280 arousals, remaining 2630
# Merged 1317 arousals, remaining 7879
# Merged 1848 arousals, remaining 6332
# Merged 739 arousals, remaining 4149
# Merged 516 arousals, remaining 4150
# Merged 891 arousals, remaining 3545
# Merged 1351 arousals, remaining 5017
# Merged 1464 arousals, remaining 6542
# Merged 1129 arousals, remaining 5127
# Merged 1426 arousals, remaining 8493
# Merged 606 arousals, remaining 5265
# Merged 1380 arousals, remaining 8044
# Merged 1054 arousals, remaining 4090
# Merged 562 arousals, remaining 3931
# Merged 1074 arousals, remaining 7470
# Merged 1203 arousals, remaining 7692
# Merged 1795 arousals, remaining 3493
# Merged 666 arousals, remaining 5865
# Processing 640 3 15
# Merged 1012 arousals, remaining 5349
# Merged 2214 arousals, remaining 9401
# Merged 1791 arousals, remaining 6350
# Merged 2291 arousals, remaining 10060
# Merged 2648 arousals, remaining 12641
# Merged 3807 arousals, remaining 8703
# Merged 1219 arousals, remaining 7444
# Merged 4587 arousals, remaining 5412
# Merged 1838 arousals, remaining 8502
# Merged 2426 arousals, remaining 7451
# Merged 2642 arousals, remaining 9371
# Merged 2428 arousals, remaining 10293
# Merged 1255 arousals, remaining 8781
# Merged 3028 arousals, remaining 11353
# Merged 4102 arousals, remaining 8931
# Merged 4161 arousals, remaining 6124
# Merged 3558 arousals, remaining 13982
# Merged 1858 arousals, remaining 9044
# Merged 2650 arousals, remaining 7652
# Merged 2925 arousals, remaining 8430
# Merged 2919 arousals, remaining 10819
# Merged 2718 arousals, remaining 7375
# Merged 2728 arousals, remaining 11573
# Merged 2650 arousals, remaining 14201
# Merged 1406 arousals, remaining 8481
# Merged 1867 arousals, remaining 6710
# Merged 2210 arousals, remaining 5778
# Merged 2089 arousals, remaining 6566
# Merged 1841 arousals, remaining 7935
# Merged 2430 arousals, remaining 6731
# Merged 1114 arousals, remaining 5556
# Merged 2270 arousals, remaining 5857
# Merged 3820 arousals, remaining 11534
# Merged 1079 arousals, remaining 5305
# Merged 1429 arousals, remaining 6881
# Merged 1611 arousals, remaining 6704
# Merged 3258 arousals, remaining 6323
# Merged 1485 arousals, remaining 5713
# Merged 2739 arousals, remaining 9169
# Merged 1414 arousals, remaining 6684
# Merged 2604 arousals, remaining 10509
# Merged 1813 arousals, remaining 3331
# Merged 2792 arousals, remaining 7662
# Merged 1534 arousals, remaining 11848
# Merged 3197 arousals, remaining 12341
# Merged 1452 arousals, remaining 7955
# Merged 2483 arousals, remaining 11209
# Merged 1902 arousals, remaining 9868
# Merged 1567 arousals, remaining 6486
# Merged 2569 arousals, remaining 6983
# Merged 3369 arousals, remaining 7205
# Merged 2654 arousals, remaining 7876
# Merged 1966 arousals, remaining 7816
# Merged 544 arousals, remaining 3536
# Merged 1139 arousals, remaining 7514
# Merged 626 arousals, remaining 6667
# Merged 346 arousals, remaining 4747
# Merged 501 arousals, remaining 5611
# Merged 728 arousals, remaining 5717
# Merged 660 arousals, remaining 4812
# Merged 247 arousals, remaining 3229
# Merged 2395 arousals, remaining 8523
# Merged 249 arousals, remaining 2348
# Merged 739 arousals, remaining 8978
# Merged 941 arousals, remaining 4107
# Merged 926 arousals, remaining 6265
# Merged 2244 arousals, remaining 10747
# Merged 678 arousals, remaining 5234
# Merged 1477 arousals, remaining 6427
# Merged 838 arousals, remaining 5041
# Merged 1003 arousals, remaining 5054
# Merged 2056 arousals, remaining 6084
# Merged 2307 arousals, remaining 9500
# Merged 368 arousals, remaining 4185
# Merged 304 arousals, remaining 4988
# Merged 799 arousals, remaining 6955
# Merged 1207 arousals, remaining 6529
# Merged 778 arousals, remaining 6649
# Merged 1300 arousals, remaining 7841
# Merged 837 arousals, remaining 5964
# Merged 1022 arousals, remaining 6153
# Merged 1948 arousals, remaining 10617
# Merged 1325 arousals, remaining 5810
# Merged 2091 arousals, remaining 8649
# Merged 1935 arousals, remaining 8496
# Merged 1094 arousals, remaining 2998
# Merged 683 arousals, remaining 4517
# Merged 1549 arousals, remaining 8866
# Merged 943 arousals, remaining 5413
# Merged 1195 arousals, remaining 6574
# Merged 1221 arousals, remaining 8142
# Merged 943 arousals, remaining 4960
# Merged 1498 arousals, remaining 5141
# Merged 639 arousals, remaining 3567
# Merged 505 arousals, remaining 4357
# Merged 703 arousals, remaining 6310
# Merged 3629 arousals, remaining 6536
# Merged 412 arousals, remaining 3188
# Merged 1947 arousals, remaining 9462
# Merged 2653 arousals, remaining 7483
# Merged 1094 arousals, remaining 4961
# Merged 789 arousals, remaining 5168
# Merged 1240 arousals, remaining 4194
# Merged 1960 arousals, remaining 6003
# Merged 2004 arousals, remaining 7717
# Merged 1655 arousals, remaining 6094
# Merged 2077 arousals, remaining 10132
# Merged 1028 arousals, remaining 6452
# Merged 2369 arousals, remaining 9711
# Merged 1482 arousals, remaining 4716
# Merged 832 arousals, remaining 4774
# Merged 1625 arousals, remaining 8923
# Merged 2017 arousals, remaining 10341
# Merged 2677 arousals, remaining 4225
# Merged 1065 arousals, remaining 7180
# Processing 960 3 15
# Merged 1718 arousals, remaining 6201
# Merged 3465 arousals, remaining 10766
# Merged 2682 arousals, remaining 7396
# Merged 3517 arousals, remaining 12019
# Merged 4671 arousals, remaining 15063
# Merged 5953 arousals, remaining 10093
# Merged 1908 arousals, remaining 8459
# Merged 7115 arousals, remaining 6225
# Merged 3103 arousals, remaining 10014
# Merged 3774 arousals, remaining 8595
# Merged 4092 arousals, remaining 10793
# Merged 3534 arousals, remaining 11437
# Merged 2090 arousals, remaining 10360
# Merged 4794 arousals, remaining 13383
# Merged 6558 arousals, remaining 10430
# Merged 5960 arousals, remaining 7121
# Merged 5456 arousals, remaining 15830
# Merged 2772 arousals, remaining 10215
# Merged 4210 arousals, remaining 8807
# Merged 4639 arousals, remaining 9870
# Merged 4363 arousals, remaining 12575
# Merged 3915 arousals, remaining 8440
# Merged 4244 arousals, remaining 13652
# Merged 4456 arousals, remaining 17034
# Merged 2072 arousals, remaining 9492
# Merged 2654 arousals, remaining 7632
# Merged 3776 arousals, remaining 6525
# Merged 3633 arousals, remaining 7837
# Merged 2893 arousals, remaining 9029
# Merged 3774 arousals, remaining 7899
# Merged 1905 arousals, remaining 6509
# Merged 3455 arousals, remaining 6683
# Merged 5982 arousals, remaining 14816
# Merged 1590 arousals, remaining 5862
# Merged 2276 arousals, remaining 7989
# Merged 2410 arousals, remaining 7542
# Merged 4587 arousals, remaining 7064
# Merged 2317 arousals, remaining 6548
# Merged 4902 arousals, remaining 10921
# Merged 2237 arousals, remaining 7717
# Merged 4058 arousals, remaining 12158
# Merged 2709 arousals, remaining 3787
# Merged 3955 arousals, remaining 8812
# Merged 2516 arousals, remaining 14154
# Merged 5501 arousals, remaining 14878
# Merged 2280 arousals, remaining 9003
# Merged 4138 arousals, remaining 13388
# Merged 3036 arousals, remaining 11683
# Merged 2618 arousals, remaining 8433
# Merged 3836 arousals, remaining 7883
# Merged 4919 arousals, remaining 8449
# Merged 4059 arousals, remaining 9236
# Merged 3163 arousals, remaining 8965
# Merged 801 arousals, remaining 3875
# Merged 1725 arousals, remaining 8661
# Merged 993 arousals, remaining 7637
# Merged 635 arousals, remaining 5554
# Merged 817 arousals, remaining 6423
# Merged 1226 arousals, remaining 6576
# Merged 1032 arousals, remaining 5446
# Merged 431 arousals, remaining 3650
# Merged 3705 arousals, remaining 10057
# Merged 376 arousals, remaining 2701
# Merged 1348 arousals, remaining 10632
# Merged 1399 arousals, remaining 4592
# Merged 1412 arousals, remaining 7038
# Merged 3583 arousals, remaining 12241
# Merged 1066 arousals, remaining 6002
# Merged 2252 arousals, remaining 7246
# Merged 1358 arousals, remaining 5796
# Merged 1529 arousals, remaining 5661
# Merged 2864 arousals, remaining 6994
# Merged 3456 arousals, remaining 10571
# Merged 607 arousals, remaining 4843
# Merged 511 arousals, remaining 5824
# Merged 1349 arousals, remaining 8311
# Merged 1862 arousals, remaining 7246
# Merged 1276 arousals, remaining 7654
# Merged 1995 arousals, remaining 9026
# Merged 1297 arousals, remaining 6827
# Merged 1552 arousals, remaining 7184
# Merged 2961 arousals, remaining 12553
# Merged 2079 arousals, remaining 6614
# Merged 3341 arousals, remaining 10270
# Merged 2757 arousals, remaining 9679
# Merged 1640 arousals, remaining 3440
# Merged 1006 arousals, remaining 5386
# Merged 2357 arousals, remaining 9878
# Merged 1551 arousals, remaining 6473
# Merged 1897 arousals, remaining 7390
# Merged 1875 arousals, remaining 9369
# Merged 1492 arousals, remaining 5701
# Merged 2031 arousals, remaining 5650
# Merged 990 arousals, remaining 3942
# Merged 706 arousals, remaining 5067
# Merged 1114 arousals, remaining 7306
# Merged 5398 arousals, remaining 7441
# Merged 625 arousals, remaining 3658
# Merged 2883 arousals, remaining 10906
# Merged 3711 arousals, remaining 8451
# Merged 1720 arousals, remaining 5705
# Merged 1265 arousals, remaining 6085
# Merged 1856 arousals, remaining 4696
# Merged 2929 arousals, remaining 6880
# Merged 3054 arousals, remaining 8869
# Merged 2314 arousals, remaining 6886
# Merged 3071 arousals, remaining 11763
# Merged 1711 arousals, remaining 7471
# Merged 3518 arousals, remaining 11089
# Merged 2104 arousals, remaining 5227
# Merged 1247 arousals, remaining 5460
# Merged 2771 arousals, remaining 10733
# Merged 3022 arousals, remaining 12033
# ...
# Merged 2126 arousals, remaining 3631
# Merged 1732 arousals, remaining 3187
# Merged 3709 arousals, remaining 3431
# Merged 1819 arousals, remaining 2534
# Merged 3202 arousals, remaining 5419
# Merged 1461 arousals, remaining 2652
# Merged 3597 arousals, remaining 5335
# Merged 1673 arousals, remaining 1751
# Merged 2613 arousals, remaining 2973
# Merged 1729 arousals, remaining 4920
# Merged 4533 arousals, remaining 7728
# Merged 2250 arousals, remaining 3650
# Merged 2153 arousals, remaining 4318
# Merged 2788 arousals, remaining 3577
# Merged 2635 arousals, remaining 4688
# Merged 2725 arousals, remaining 3023
# Merged 3393 arousals, remaining 3389
# Merged 4401 arousals, remaining 4720
# Merged 2257 arousals, remaining 3771
# Merged 671 arousals, remaining 1297
# Merged 1168 arousals, remaining 3169
# Merged 962 arousals, remaining 4858
# Merged 444 arousals, remaining 2368
# Merged 396 arousals, remaining 1596
# Merged 920 arousals, remaining 2350
# Merged 733 arousals, remaining 1682
# Merged 333 arousals, remaining 1404
# Merged 2431 arousals, remaining 4363
# Merged 297 arousals, remaining 820
# Merged 1651 arousals, remaining 9637
# Merged 1320 arousals, remaining 1414
# Merged 885 arousals, remaining 2051
# Merged 3187 arousals, remaining 5256
# Merged 831 arousals, remaining 2027
# Merged 1202 arousals, remaining 2100
# Merged 1286 arousals, remaining 2068
# Merged 977 arousals, remaining 1750
# Merged 1616 arousals, remaining 2695
# Merged 5708 arousals, remaining 3180
# Merged 672 arousals, remaining 1866
# Merged 408 arousals, remaining 1820
# Merged 699 arousals, remaining 2279
# Merged 1724 arousals, remaining 3149
# Merged 1137 arousals, remaining 2049
# Merged 1581 arousals, remaining 2729
# Merged 1347 arousals, remaining 2258
# Merged 811 arousals, remaining 2740
# Merged 2195 arousals, remaining 3640
# Merged 1287 arousals, remaining 2195
# Merged 2099 arousals, remaining 4508
# Merged 3365 arousals, remaining 3761
# Merged 1585 arousals, remaining 2011
# Merged 668 arousals, remaining 2181
# Merged 2383 arousals, remaining 3117
# Merged 880 arousals, remaining 1812
# Merged 2652 arousals, remaining 3383
# Merged 1127 arousals, remaining 2595
# Merged 1570 arousals, remaining 2846
# Merged 1793 arousals, remaining 2757
# Merged 609 arousals, remaining 1429
# Merged 523 arousals, remaining 2236
# Merged 804 arousals, remaining 1854
# Merged 1664 arousals, remaining 2214
# Merged 387 arousals, remaining 1399
# Merged 3318 arousals, remaining 4030
# Merged 2824 arousals, remaining 4007
# Merged 832 arousals, remaining 1768
# Merged 878 arousals, remaining 1585
# Merged 1215 arousals, remaining 1654
# Merged 2130 arousals, remaining 2187
# Merged 2894 arousals, remaining 4533
# Merged 2556 arousals, remaining 3253
# Merged 3080 arousals, remaining 7061
# Merged 2268 arousals, remaining 3331
# Merged 3499 arousals, remaining 4289
# Merged 2067 arousals, remaining 2565
# Merged 777 arousals, remaining 1674
# Merged 2803 arousals, remaining 3812
# Merged 2486 arousals, remaining 3492
# Merged 1711 arousals, remaining 1816
# Merged 1614 arousals, remaining 3264
# Processing 960 3 15
# Merged 2500 arousals, remaining 3571
# Merged 6108 arousals, remaining 10223
# Merged 3066 arousals, remaining 4214
# Merged 4247 arousals, remaining 6165
# Merged 5963 arousals, remaining 9707
# Merged 7102 arousals, remaining 6651
# Merged 2578 arousals, remaining 3711
# Merged 12004 arousals, remaining 4854
# Merged 3972 arousals, remaining 5276
# Merged 4686 arousals, remaining 5523
# Merged 7316 arousals, remaining 6813
# Merged 4226 arousals, remaining 5180
# Merged 3062 arousals, remaining 6914
# Merged 7852 arousals, remaining 8438
# Merged 8666 arousals, remaining 8887
# Merged 2741 arousals, remaining 2952
# Merged 8917 arousals, remaining 9350
# Merged 5594 arousals, remaining 7447
# Merged 4727 arousals, remaining 4622
# Merged 5217 arousals, remaining 5979
# Merged 6039 arousals, remaining 6965
# Merged 4081 arousals, remaining 4228
# Merged 4732 arousals, remaining 5852
# Merged 7676 arousals, remaining 18751
# Merged 4123 arousals, remaining 7754
# Merged 2901 arousals, remaining 3322
# Merged 4218 arousals, remaining 4047
# Merged 3960 arousals, remaining 6089
# Merged 5474 arousals, remaining 4877
# Merged 6181 arousals, remaining 7135
# Merged 2599 arousals, remaining 5101
# Merged 4404 arousals, remaining 3679
# Merged 8868 arousals, remaining 10838
# Merged 11550 arousals, remaining 21373
# Merged 3548 arousals, remaining 4988
# Merged 2737 arousals, remaining 4197
# Merged 5712 arousals, remaining 4283
# Merged 3070 arousals, remaining 3357
# Merged 5628 arousals, remaining 7760
# Merged 2169 arousals, remaining 3530
# Merged 5817 arousals, remaining 7302
# Merged 2713 arousals, remaining 2225
# Merged 3936 arousals, remaining 3893
# Merged 2832 arousals, remaining 6863
# Merged 8475 arousals, remaining 11165
# Merged 3528 arousals, remaining 4899
# Merged 3676 arousals, remaining 6010
# Merged 4535 arousals, remaining 4708
# Merged 4688 arousals, remaining 7058
# Merged 4064 arousals, remaining 3741
# Merged 5412 arousals, remaining 4439
# Merged 7180 arousals, remaining 6418
# Merged 3893 arousals, remaining 5101
# Merged 1000 arousals, remaining 1582
# Merged 1801 arousals, remaining 4156
# Merged 1542 arousals, remaining 6158
# Merged 676 arousals, remaining 3229
# Merged 757 arousals, remaining 2034
# Merged 1515 arousals, remaining 3211
# Merged 1221 arousals, remaining 2256
# Merged 574 arousals, remaining 1857
# Merged 4116 arousals, remaining 6042
# Merged 440 arousals, remaining 1012
# Merged 2987 arousals, remaining 13118
# Merged 1888 arousals, remaining 1728
# Merged 1294 arousals, remaining 2615
# Merged 5076 arousals, remaining 6984
# Merged 1320 arousals, remaining 2649
# Merged 1859 arousals, remaining 2690
# Merged 2023 arousals, remaining 2831
# Merged 1427 arousals, remaining 2165
# Merged 2532 arousals, remaining 3297
# Merged 8532 arousals, remaining 4189
# Merged 1088 arousals, remaining 2490
# Merged 747 arousals, remaining 2427
# Merged 1210 arousals, remaining 3114
# Merged 2835 arousals, remaining 4107
# Merged 1932 arousals, remaining 2669
# Merged 2443 arousals, remaining 3470
# Merged 2286 arousals, remaining 2886
# Merged 1411 arousals, remaining 3822
# Merged 3372 arousals, remaining 4908
# Merged 2216 arousals, remaining 2839
# Merged 3616 arousals, remaining 6397
# Merged 5032 arousals, remaining 4836
# Merged 2401 arousals, remaining 2557
# Merged 968 arousals, remaining 2916
# Merged 3477 arousals, remaining 3780
# Merged 1520 arousals, remaining 2530
# Merged 4061 arousals, remaining 4429
# Merged 1875 arousals, remaining 3290
# Merged 2480 arousals, remaining 3770
# Merged 2604 arousals, remaining 3232
# Merged 971 arousals, remaining 1789
# Merged 779 arousals, remaining 2837
# Merged 1291 arousals, remaining 2533
# Merged 3341 arousals, remaining 2872
# Merged 615 arousals, remaining 1776
# Merged 5168 arousals, remaining 5244
# Merged 4604 arousals, remaining 5192
# Merged 1408 arousals, remaining 2302
# Merged 1441 arousals, remaining 2115
# Merged 1979 arousals, remaining 2026
# Merged 3348 arousals, remaining 2722
# Merged 5164 arousals, remaining 5933
# Merged 3812 arousals, remaining 4245
# Merged 4754 arousals, remaining 9136
# Merged 3351 arousals, remaining 4337
# Merged 5732 arousals, remaining 5753
# Merged 3075 arousals, remaining 3130
# Merged 1278 arousals, remaining 2034
# Merged 4575 arousals, remaining 5658
# Merged 3808 arousals, remaining 4483
# Merged 2539 arousals, remaining 2278
# Merged 2496 arousals, remaining 4536
# Processing 1920 3 15
# Merged 5299 arousals, remaining 5369
# Merged 13889 arousals, remaining 15225
# Merged 6321 arousals, remaining 6141
# Merged 8627 arousals, remaining 10112
# Merged 13513 arousals, remaining 15098
# Merged 14169 arousals, remaining 9759
# Merged 5252 arousals, remaining 5780
# Merged 25722 arousals, remaining 7397
# Merged 8588 arousals, remaining 8280
# Merged 10174 arousals, remaining 8148
# Merged 17810 arousals, remaining 10494
# Merged 9136 arousals, remaining 7557
# Merged 6845 arousals, remaining 10584
# Merged 19135 arousals, remaining 14096
# Merged 18935 arousals, remaining 13696
# Merged 5623 arousals, remaining 4163
# Merged 19870 arousals, remaining 14593
# Merged 12177 arousals, remaining 11318
# Merged 11939 arousals, remaining 7085
# Merged 11847 arousals, remaining 8772
# Merged 12530 arousals, remaining 10340
# Merged 8382 arousals, remaining 6082
# Merged 10945 arousals, remaining 9537
# Merged 16460 arousals, remaining 30112
# Merged 9126 arousals, remaining 11799
# Merged 6322 arousals, remaining 5075
# Merged 12356 arousals, remaining 5992
# Merged 10066 arousals, remaining 10429
# Merged 12576 arousals, remaining 7059
# Merged 15202 arousals, remaining 12559
# Merged 5233 arousals, remaining 7777
# Merged 9777 arousals, remaining 5350
# Merged 19676 arousals, remaining 17527
# Merged 15190 arousals, remaining 26054
# Merged 7790 arousals, remaining 8216
# Merged 5729 arousals, remaining 6435
# Merged 12662 arousals, remaining 6249
# Merged 7072 arousals, remaining 5369
# Merged 13982 arousals, remaining 13012
# Merged 4454 arousals, remaining 5126
# Merged 12829 arousals, remaining 11600
# Merged 6089 arousals, remaining 3060
# Merged 7563 arousals, remaining 5765
# Merged 5620 arousals, remaining 10745
# Merged 21130 arousals, remaining 20423
# Merged 6930 arousals, remaining 6999
# Merged 8116 arousals, remaining 9363
# Merged 10628 arousals, remaining 7064
# Merged 10410 arousals, remaining 12759
# Merged 8393 arousals, remaining 5587
# Merged 10604 arousals, remaining 6439
# Merged 15339 arousals, remaining 9768
# Merged 8690 arousals, remaining 7774
# Merged 1875 arousals, remaining 2190
# Merged 3570 arousals, remaining 6022
# Merged 2992 arousals, remaining 8476
# Merged 1517 arousals, remaining 4522
# Merged 1770 arousals, remaining 2996
# Merged 2965 arousals, remaining 4670
# Merged 2716 arousals, remaining 3274
# Merged 1106 arousals, remaining 2679
# Merged 8146 arousals, remaining 9453
# Merged 886 arousals, remaining 1359
# Merged 7730 arousals, remaining 20773
# Merged 3412 arousals, remaining 2371
# Merged 2519 arousals, remaining 3609
# Merged 11042 arousals, remaining 11141
# Merged 2696 arousals, remaining 3966
# Merged 3707 arousals, remaining 3822
# Merged 4388 arousals, remaining 4286
# Merged 2715 arousals, remaining 3107
# Merged 4659 arousals, remaining 4437
# Merged 16060 arousals, remaining 5963
# Merged 2452 arousals, remaining 3683
# Merged 1569 arousals, remaining 3671
# Merged 2505 arousals, remaining 4814
# Merged 5620 arousals, remaining 5832
# Merged 4293 arousals, remaining 3938
# Merged 4704 arousals, remaining 5012
# Merged 4570 arousals, remaining 4019
# Merged 2892 arousals, remaining 5642
# Merged 5996 arousals, remaining 7473
# Merged 4988 arousals, remaining 4338
# Merged 7221 arousals, remaining 9913
# Merged 10580 arousals, remaining 7012
# Merged 4848 arousals, remaining 3624
# Merged 1783 arousals, remaining 4071
# Merged 6880 arousals, remaining 5078
# Merged 3332 arousals, remaining 4027
# Merged 9190 arousals, remaining 6586
# Merged 3944 arousals, remaining 5056
# Merged 5214 arousals, remaining 5621
# Merged 5085 arousals, remaining 4118
# Merged 2210 arousals, remaining 2511
# Merged 1471 arousals, remaining 3844
# Merged 2795 arousals, remaining 3706
# Merged 7531 arousals, remaining 4292
# Merged 1307 arousals, remaining 2592
# Merged 10222 arousals, remaining 7668
# Merged 8964 arousals, remaining 7536
# Merged 3269 arousals, remaining 3203
# Merged 3157 arousals, remaining 3033
# Merged 4288 arousals, remaining 2837
# Merged 6479 arousals, remaining 3784
# Merged 10559 arousals, remaining 8574
# Merged 7073 arousals, remaining 6080
# Merged 9336 arousals, remaining 13110
# Merged 6593 arousals, remaining 6308
# Merged 12240 arousals, remaining 8490
# Merged 5630 arousals, remaining 4111
# Merged 2519 arousals, remaining 2853
# Merged 10645 arousals, remaining 9653
# Merged 7761 arousals, remaining 6243
# Merged 5376 arousals, remaining 3103
# Merged 5203 arousals, remaining 7198
# Processing 3840 3 15
# Merged 16014 arousals, remaining 7509
# Merged 27327 arousals, remaining 21470
# Merged 11892 arousals, remaining 8597
# Merged 17538 arousals, remaining 15639
# Merged 24781 arousals, remaining 20925
# Merged 25498 arousals, remaining 12989
# Merged 17018 arousals, remaining 8419
# Merged 145108 arousals, remaining 28748
# Merged 24903 arousals, remaining 12161
# Merged 19335 arousals, remaining 11433
# Merged 33875 arousals, remaining 14198
# Merged 17008 arousals, remaining 10353
# Merged 12860 arousals, remaining 15224
# Merged 39288 arousals, remaining 19627
# Merged 36086 arousals, remaining 18972
# Merged 11617 arousals, remaining 5424
# Merged 35666 arousals, remaining 20217
# Merged 22814 arousals, remaining 15883
# Merged 26008 arousals, remaining 9863
# Merged 23697 arousals, remaining 12101
# Merged 22859 arousals, remaining 14309
# Merged 15901 arousals, remaining 8124
# Merged 22324 arousals, remaining 13045
# Merged 28158 arousals, remaining 41669
# Merged 16262 arousals, remaining 16178
# Merged 12020 arousals, remaining 6998
# Merged 29024 arousals, remaining 7971
# Merged 20632 arousals, remaining 15366
# Merged 24447 arousals, remaining 9918
# Merged 31371 arousals, remaining 16854
# Merged 9785 arousals, remaining 10573
# Merged 18991 arousals, remaining 7359
# Merged 35766 arousals, remaining 24737
# Merged 20889 arousals, remaining 35882
# Merged 26059 arousals, remaining 13174
# Merged 12314 arousals, remaining 8935
# Merged 24570 arousals, remaining 8104
# Merged 13075 arousals, remaining 7655
# Merged 27229 arousals, remaining 18806
# Merged 9450 arousals, remaining 7029
# Merged 26724 arousals, remaining 17131
# Merged 13507 arousals, remaining 4192
# Merged 26991 arousals, remaining 8694
# Merged 15557 arousals, remaining 14980
# Merged 70397 arousals, remaining 30129
# Merged 53672 arousals, remaining 16602
# Merged 15337 arousals, remaining 12695
# Merged 21393 arousals, remaining 9908
# Merged 18231 arousals, remaining 19377
# Merged 16382 arousals, remaining 7844
# Merged 29450 arousals, remaining 8877
# Merged 27197 arousals, remaining 13517
# Merged 16749 arousals, remaining 10806
# Merged 3446 arousals, remaining 2907
# Merged 6822 arousals, remaining 8360
# Merged 5842 arousals, remaining 11393
# Merged 3104 arousals, remaining 6305
# Merged 3530 arousals, remaining 4176
# Merged 5231 arousals, remaining 6558
# Merged 5411 arousals, remaining 4458
# Merged 2014 arousals, remaining 3652
# Merged 13672 arousals, remaining 12336
# Merged 1682 arousals, remaining 1877
# Merged 14270 arousals, remaining 29275
# Merged 6432 arousals, remaining 3154
# Merged 4686 arousals, remaining 4907
# Merged 20253 arousals, remaining 15606
# Merged 4844 arousals, remaining 5348
# Merged 6954 arousals, remaining 5321
# Merged 7859 arousals, remaining 5973
# Merged 5009 arousals, remaining 4233
# Merged 8374 arousals, remaining 5941
# Merged 29964 arousals, remaining 7900
# Merged 4741 arousals, remaining 5102
# Merged 2849 arousals, remaining 5206
# Merged 4553 arousals, remaining 6741
# Merged 9939 arousals, remaining 7880
# Merged 7842 arousals, remaining 5357
# Merged 8461 arousals, remaining 6850
# Merged 7921 arousals, remaining 5397
# Merged 5199 arousals, remaining 7889
# Merged 10151 arousals, remaining 10298
# Merged 9567 arousals, remaining 5817
# Merged 13942 arousals, remaining 14263
# Merged 18589 arousals, remaining 9795
# Merged 8737 arousals, remaining 4843
# Merged 3343 arousals, remaining 5597
# Merged 12973 arousals, remaining 6711
# Merged 6324 arousals, remaining 5609
# Merged 18067 arousals, remaining 9208
# Merged 7076 arousals, remaining 6808
# Merged 9372 arousals, remaining 7703
# Merged 9807 arousals, remaining 5316
# Merged 4495 arousals, remaining 3416
# Merged 2843 arousals, remaining 5190
# Merged 5072 arousals, remaining 5298
# Merged 15440 arousals, remaining 5967
# Merged 2656 arousals, remaining 3398
# Merged 18637 arousals, remaining 10348
# Merged 16233 arousals, remaining 10253
# Merged 6182 arousals, remaining 4414
# Merged 5762 arousals, remaining 4065
# Merged 8775 arousals, remaining 3813
# Merged 11688 arousals, remaining 5199
# Merged 18108 arousals, remaining 11332
# Merged 12192 arousals, remaining 8406
# Merged 16977 arousals, remaining 17603
# Merged 12533 arousals, remaining 8476
# Merged 20610 arousals, remaining 11563
# Merged 9925 arousals, remaining 5473
# Merged 5104 arousals, remaining 3969
# Merged 19921 arousals, remaining 13739
# Merged 14969 arousals, remaining 8417
# Merged 10584 arousals, remaining 4138
# Merged 9989 arousals, remaining 10025

# %%
# JSON serializer for numpy arrays
class NumpyArrayEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NumpyArrayEncoder, self).default(obj)


with open('arousals_aasm_merged.json', 'w') as f:
    json.dump(pred_arousals, f, cls=NumpyArrayEncoder)

# %%
def calc_tp_fp_fn(gt_arousals, pred_arousals, overlap_thresholds):
    tp, fp = [0] * len(overlap_thresholds), [0] * len(overlap_thresholds)
    if len(gt_arousals) > 0:
        gt_arousals = gt_arousals[:, :2].astype(float)

    used_gt_ar = [np.zeros(len(gt_arousals))] * len(overlap_thresholds)
    gt_start = 0
    for pred_s in pred_arousals:
        intersects = [0] * len(gt_arousals)
        unions = [0] * len(gt_arousals)
        for gt_i in range(gt_start, len(gt_arousals)):
            gt_s = gt_arousals[gt_i]
            if pred_s[1] < gt_s[0]:
                break
            if pred_s[0] > gt_s[1]:
                gt_start = gt_i + 1
                continue
            intersects[gt_i] = min(gt_s[1], pred_s[1]) - max(gt_s[0], pred_s[0])
            unions[gt_i] = max(gt_s[1], pred_s[1]) - min(gt_s[0], pred_s[0])
        ious = [intersects[i] / unions[i] if unions[i] > 0 else 0
                for i in range(len(intersects))]
        for i, ovt in enumerate(overlap_thresholds):
            if len(ious) > 0 and max(ious) > ovt:
                tp[i] += 1
                used_gt_ar[i][np.argmax(ious)] = 1
            else:
                fp[i] += 1

    fn = [len(gt_arousals) - np.sum(used_gt_ar[i]) for i in range(len(overlap_thresholds))]

    return np.array(tp), np.array(fp), np.array(fn)

# %%
overlap_thresholds = np.linspace(0, 1, 11)

scores = {}

for model in pred_arousals.keys():
    scores[model] = {}

    for ss_sr in pred_arousals[model].keys():
        scores[model][ss_sr] = {}

        lower_wake_length = 3
        upper_wake_length = 15

        print(f"Processing {ss_sr} {lower_wake_length} {upper_wake_length}")

        for s_id_ss in pred_arousals[model][ss_sr].keys():
            pred_ar = pred_arousals[model][ss_sr][s_id_ss]
            gt_ar = all_arousals[s_id_ss.split('_')[1]]
            tp, fp, fn = calc_tp_fp_fn(gt_ar, pred_ar, overlap_thresholds)
            prec = [tp[i] / (tp[i] + fp[i]) if tp[i] + fp[i] > 0 else 0 for i in range(len(overlap_thresholds))]
            rec = [tp[i] / (tp[i] + fn[i]) if tp[i] + fn[i] > 0 else 0 for i in range(len(overlap_thresholds))]
            f1 = [2 * tp[i] / (2 * tp[i] + fp[i] + fn[i]) if tp[i] + fp[i] + fn[i] > 0 else 0
                  for i in range(len(overlap_thresholds))]
            scores[model][ss_sr][s_id_ss] = {"prec": prec, "rec": rec, "f1": f1}
# Out:
# Processing 1 3 15
# Processing 2 3 15
# Processing 4 3 15
# Processing 8 3 15
# Processing 16 3 15
# Processing 32 3 15
# Processing 64 3 15
# Processing 128 3 15
# Processing 256 3 15
# Processing 384 3 15
# Processing 640 3 15
# Processing 960 3 15
# Processing 1920 3 15
# Processing 3840 3 15
# Processing 1 3 15
# Processing 2 3 15
# Processing 4 3 15
# Processing 8 3 15
# Processing 16 3 15
# Processing 32 3 15
# Processing 64 3 15
# Processing 128 3 15
# Processing 256 3 15
# Processing 384 3 15
# Processing 640 3 15
# Processing 960 3 15
# Processing 1920 3 15
# Processing 3840 3 15
# Processing 1 3 15
# Processing 2 3 15
# Processing 4 3 15
# Processing 8 3 15
# Processing 16 3 15
# Processing 32 3 15
# Processing 64 3 15
# Processing 128 3 15
# Processing 256 3 15
# Processing 384 3 15
# Processing 640 3 15
# Processing 960 3 15
# Processing 1920 3 15
# Processing 3840 3 15

# %%
# save f1s to json
with open('arousals_iou_scores_aasm_merged.json', 'w') as f:
    json.dump(scores, f)
